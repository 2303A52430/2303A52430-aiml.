# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52430/2303A52430-aiml./blob/main/Lab08_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fetch_openml(data_id=5).keys
# Out:
# <function Bunch.keys>

# %%
from sklearn.datasets import fetch_openml

car_data = fetch_openml(name='car', version=2,
                        parser='auto')

# %%
type(car_data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
car_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
car_data.feature_names, car_data.target.value_counts()
# Out:
# (['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'],
#  binaryClass
#  P    1210
#  N     518
#  Name: count, dtype: int64)

# %%
print(car_data.DESCR)
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# Binarized version of the original data set (see version 1). The multi-class target feature is converted to a two-class nominal target feature by re-labeling the majority class as positive ('P') and all others as negative ('N'). Originally converted by Quan Sun.
#
# Downloaded from openml.org.

# %%
car_data.feature_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety']

# %%
car_data = car_data.frame
car_data.head()
# Out:
#   buying  maint doors persons lug_boot safety binaryClass
# 0  vhigh  vhigh     2       2    small    low           P
# 1  vhigh  vhigh     2       2    small    med           P
# 2  vhigh  vhigh     2       2    small   high           P
# 3  vhigh  vhigh     2       2      med    low           P
# 4  vhigh  vhigh     2       2      med    med           P

# %%
type(car_data)
# Out:
# pandas.core.frame.DataFrame

# %%
l = len(car_data.columns)
for i in range(l):
  sns.jointplot(x=car_data.columns[i],y='binaryClass',
              data=car_data,palette='rainbow')

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(car_data, test_size=0.2,
                                         random_state=220)

#print('Dataset size:{}\ntraining data is: {}\n
#testing data is: {}'.format(len(car_data),
#                            len(train_data),len(test_data)))
car_data.shape, train_data.shape, test_data.shape
# Out:
# ((1728, 7), (1382, 7), (346, 7))

# %%
train_data.describe()
# Out:
#        buying maint doors persons lug_boot safety binaryClass
# count    1382  1382  1382    1382     1382   1382        1382
# unique      4     4     4       3        3      3           2
# top     vhigh   med     2       2    small   high           P
# freq      356   355   352     476      478    468         972

# %%
train_data.isnull().sum()
# Out:
# buying         0
# maint          0
# doors          0
# persons        0
# lug_boot       0
# safety         0
# binaryClass    0
# dtype: int64

# %% [markdown]
# We don't have any missing values.

# %%
train_data.columns
# Out:
# Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety',
#        'binaryClass'],
#       dtype='object')

# %%
train_data['buying'].value_counts()
# Out:
# buying
# vhigh    356
# low      349
# med      339
# high     338
# Name: count, dtype: int64

# %%
train_data['maint'].value_counts()
# Out:
# maint
# med      355
# vhigh    347
# low      344
# high     336
# Name: count, dtype: int64

# %%
train_data['doors'].value_counts()
# Out:
# doors
# 2        352
# 5more    347
# 3        342
# 4        341
# Name: count, dtype: int64

# %%
train_data['persons'].value_counts()
# Out:
# persons
# 2       476
# 4       455
# more    451
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='buying')
# Out:
# <Axes: xlabel='buying', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='buying', hue='binaryClass')
# Out:
# <Axes: xlabel='buying', ylabel='count'>

# %%
train_data['maint'].value_counts()
# Out:
# maint
# med      355
# vhigh    347
# low      344
# high     336
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='maint')
# Out:
# <Axes: xlabel='maint', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='maint', hue='binaryClass')
# Out:
# <Axes: xlabel='maint', ylabel='count'>

# %%
train_data['doors'].value_counts()
# Out:
# doors
# 2        352
# 5more    347
# 3        342
# 4        341
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='doors')
# Out:
# <Axes: xlabel='doors', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='doors', hue='binaryClass')
# Out:
# <Axes: xlabel='doors', ylabel='count'>

# %%
train_data['persons'].value_counts()
# Out:
# persons
# 2       476
# 4       455
# more    451
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='persons', hue='binaryClass')
# Out:
# <Axes: xlabel='persons', ylabel='count'>

# %%
train_data['lug_boot'].value_counts()
# Out:
# lug_boot
# small    478
# med      466
# big      438
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='lug_boot', hue='binaryClass')
# Out:
# <Axes: xlabel='lug_boot', ylabel='count'>

# %%
train_data['safety'].value_counts()
# Out:
# safety
# high    468
# med     462
# low     452
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='safety', hue='binaryClass')
# Out:
# <Axes: xlabel='safety', ylabel='count'>

# %%
train_data['binaryClass'].value_counts()
# Out:
# binaryClass
# P    972
# N    410
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=train_data, x='binaryClass')
# Out:
# <Axes: xlabel='binaryClass', ylabel='count'>

# %%
car_train = train_data.drop('binaryClass', axis=1)
car_labels = train_data[['binaryClass']]

# %%
from sklearn.preprocessing import OrdinalEncoder

from sklearn.pipeline import Pipeline

pipe = Pipeline([('ord_enc', OrdinalEncoder())])

car_train_prepared = pipe.fit_transform(car_train)

# %%
from sklearn.preprocessing import LabelEncoder

label_enc = LabelEncoder()

car_labels_prepared = label_enc.fit_transform(car_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
car_train_prepared.shape, car_labels_prepared.shape
# Out:
# ((1382, 6), (1382,))

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier()
tree_clf.set_params(class_weight='balanced', criterion='entropy')

tree_clf.fit(car_train_prepared, car_labels_prepared)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy')

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20,15))
plot_tree(tree_clf, feature_names=car_train.columns,
          class_names=['N','P']);

# %%
# if you run this, it will be error.
# SKlearn tree implementation doesn't support categorical features

#from sklearn.tree import DecisionTreeClassifier

#tree_clf = DecisionTreeClassifier()

#tree_clf.fit(car_train, car_labels)

# %%
from sklearn.metrics import accuracy_score, classification_report,\
confusion_matrix

preds = tree_clf.predict(car_train_prepared)
print(f"Accuracy:{accuracy_score(car_labels_prepared, preds)}")
print(f"ClassReport:{classification_report(car_labels_prepared,preds)}")
print(f"Confusion Matrix:{confusion_matrix(car_labels_prepared,preds)}")
# Out:
# Accuracy:1.0
# ClassReport:              precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       410
#            1       1.00      1.00      1.00       972
#
#     accuracy                           1.00      1382
#    macro avg       1.00      1.00      1.00      1382
# weighted avg       1.00      1.00      1.00      1382
#
# Confusion Matrix:[[410   0]
#  [  0 972]]

# %%
accuracy_score(car_labels_prepared,preds)
# Out:
# 1.0

# %%
tree_clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
# Let's hide warnings returned by grid search

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import GridSearchCV

params_grid = {'max_leaf_nodes': list(range(0, 10)),
               'min_samples_split': [0,1,2, 3, 4],
               'min_samples_leaf': [0,1,2, 3, 4],
               'max_depth':[0,1,2,3,4,5],
               'max_features':[0,1,2,3,4,5],
              'max_leaf_nodes':[0,1,2,3,4,5]}

#refit is true by default. The best estimator is trained on the whole dataset

grid_search = GridSearchCV(DecisionTreeClassifier(random_state=42, class_weight='balanced'), params_grid, verbose=1, cv=3, refit=True)

grid_search.fit(car_train_prepared, car_labels_prepared)
# Out:
# Fitting 3 folds for each of 5400 candidates, totalling 16200 fits
# GridSearchCV(cv=3,
#              estimator=DecisionTreeClassifier(class_weight='balanced',
#                                               random_state=42),
#              param_grid={'max_depth': [0, 1, 2, 3, 4, 5],
#                          'max_features': [0, 1, 2, 3, 4, 5],
#                          'max_leaf_nodes': [0, 1, 2, 3, 4, 5],
#                          'min_samples_leaf': [0, 1, 2, 3, 4],
#                          'min_samples_split': [0, 1, 2, 3, 4]},
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 4,
#  'max_features': 5,
#  'max_leaf_nodes': 5,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=4, max_features=5,
#                        max_leaf_nodes=5, random_state=42)

# %%
tree_best = grid_search.best_estimator_

# %%
car_data.columns

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20,15))
plot_tree(tree_best, feature_names=car_train.columns, class_names=['N','P']);

# %%
 from sklearn.metrics import accuracy_score

# Assuming 'car_labels_prepared' are the true labels and
# 'tree_best.predict(car_train_prepared)' are the predicted labels
accuracy = accuracy_score(car_labels_prepared, tree_best.predict(car_train_prepared))
print(accuracy)
# Out:
# 0.8878437047756874

# %%
from sklearn.metrics import accuracy_score, confusion_matrix # Import confusion_matrix

# Assuming 'car_labels_prepared' are the true labels and
# 'tree_best.predict(car_train_prepared)' are the predicted labels
# accuracy = accuracy_score(car_labels_prepared, tree_best.predict(car_train_prepared))
# print(accuracy)


# Replace 'conf_matrix' with 'confusion_matrix' in the function call
conf_matrix_result = confusion_matrix(car_labels_prepared, tree_best.predict(car_train_prepared))
print(conf_matrix_result) # Print the result of confusion_matrix
# Out:
# [[381  29]
#  [126 846]]

# %%
from sklearn.metrics import classification_report # Import classification_report

# Now call the function using its correct name
report = classification_report(car_labels_prepared, tree_best.predict(car_train_prepared))
print(report) # Print the classification report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.93      0.83       410
#            1       0.97      0.87      0.92       972
#
#     accuracy                           0.89      1382
#    macro avg       0.86      0.90      0.87      1382
# weighted avg       0.90      0.89      0.89      1382

# %%
car_test = test_data.drop('binaryClass', axis=1)
car_test_labels = test_data['binaryClass']

# %%
# Handling the categorical features with the pipeline that we defined early
# We don't fit on the test data. Only transform

car_test_prepared = pipe.transform(car_test)

# %%
# Handle labels too

car_test_labels_prepared = label_enc.transform(car_test_labels)

# %%
from sklearn.metrics import accuracy_score # Import the accuracy_score function if you haven't already

# Assuming you have a function to calculate accuracy, or using accuracy_score from sklearn.metrics
def accuracy(y_true, y_pred):
    """
    Calculates the accuracy score.

    Args:
        y_true: True labels.
        y_pred: Predicted labels.

    Returns:
        Accuracy score.
    """
    return accuracy_score(y_true, y_pred)

# ... (rest of your code)

# Rename the variable storing the previous accuracy score
previous_accuracy = 0.8878437047756874  # Example value

# Calculate and print the accuracy on your test data
acc = accuracy(car_test_labels_prepared, tree_best.predict(car_test_prepared))
print(acc)
# Out:
# 0.8930635838150289

# %%
from sklearn.metrics import confusion_matrix # Import the confusion_matrix function

def conf_matrix(X_test_prepared, model, y_test_prepared):
    """
    Calculates and prints the confusion matrix.

    Args:
        X_test_prepared: Prepared test features.
        model: Trained model.
        y_test_prepared: Prepared test labels.

    Returns:
        None
    """
    y_pred = model.predict(X_test_prepared)
    cm = confusion_matrix(y_test_prepared, y_pred)
    print(cm) # Print the Confusion Matrix

# ... (rest of your code)

# Now you can use the conf_matrix function
conf_matrix(car_test_prepared, tree_best, car_test_labels_prepared)
# Out:
# [[102   6]
#  [ 31 207]]

# %%
from sklearn.metrics import classification_report # Import the classification_report function

def class_report(X_test_prepared, model, y_test_prepared):
    """
    Calculates and prints the classification report.

    Args:
        X_test_prepared: Prepared test features.
        model: Trained model.
        y_test_prepared: Prepared test labels.

    Returns:
        None
    """
    y_pred = model.predict(X_test_prepared)
    report = classification_report(y_test_prepared, y_pred)
    print(report) # Print the classification report

# ... (rest of your code)

# Now you can use the class_report function
class_report(car_test_prepared, tree_best, car_test_labels_prepared)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.94      0.85       108
#            1       0.97      0.87      0.92       238
#
#     accuracy                           0.89       346
#    macro avg       0.87      0.91      0.88       346
# weighted avg       0.91      0.89      0.90       346

# %% [markdown]
# [Back to top](#0)
